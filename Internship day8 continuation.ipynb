# %%
import cv2

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

print("OpenCV-Python Version %s" % cv2.__version__)
# Out:
# OpenCV-Python Version 4.1.0

# %%
img = cv2.imread('messi.jpg',cv2.IMREAD_COLOR)

#If the image path is wrong, the resulting img will be none
if img is None:
    print('open error')
else:
    print('Image loaded')
# Out:
# Image loaded

# %%
#display an image using matplotlib
#plt.imshow(img) # => The color of this line is wromg

plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#Check th resulting img
print(type(img))
print(img.shape)
print(img.dtype)
print(img[:2,:2,:])
# Out:
# <class 'numpy.ndarray'>
# (342, 548, 3)
# uint8
# [[[39 43 44]
#   [42 46 47]]
#
#  [[37 40 44]
#   [42 45 49]]]

# %%
#create a black image
img2 = np.zeros((512,512,3),np.uint8)
plt.imshow(img2)

# %%
#draw a line using cv2.line(image,startpoint,endpoint,rgb,thickness)
cv2.line(img2,(0,0),(511,511),(255,0,0), 5)
#=> diagonal red line with thickness of 5 px

#draw a line using cv2.rectangle(image,startpoint,endpoint,rgb,thickness)
cv2.rectangle(img2,(384,0),(510,128),(0,255,0),3)

#draw a line using cv2.circle(image,startpoint,endpoint,rgb,thickness)
cv2.circle(img2,(447,63),63,(0,0,255),-1)

#draw a line using cv2.ellipse(image,startpoint,endpoint,rgb,thickness)
cv2.ellipse(img2,(256,256),(100,50),-45,0,180,(255,0,0),-1)
plt.imshow(img2)

# %%
img[50,235]
# Out:
# array([29, 24, 25], dtype=uint8)

# %%
#change pixel values
for i in range(5):
    for j in range(5):
        img[50+i,235+j] = (0,255,0)
        
# => green dot above messis head

plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for i in range(5):
    for j in range(5):
        img[290+i,450+j] = (0,0,255)
        
#dot near shoes

plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#ROI is obtained using numpy indexing
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

#img[50:55,235:240] =(0,255,0) #the for loop  in the 
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
stud = img[250:290, 380:460]
img[250:290, 150:230] = stud

stud2 = img[301:333, 251:310]
img[301:333, 162:221] = stud2
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
